# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from plot_utils import *
from preprocess_datasets import get_shot_list, make_training_sets, DEFAULT_FEATURES
from run_models import load_model

device = 'cmod'
#dataset = 'random100'
dataset = 'random_256_shots_60%_flattop'
#device = 'synthetic'
#dataset= 'synthetic100'

make_training_sets(device, dataset, random_seed=0)

# Get list of training shots
train_shots = get_shot_list(device, dataset+'_train')

#for shot in train_shots:
#    plot_horizon(device, dataset+'_train', shot, transformer)

plot_horizon(device, dataset+'_test', 1120106009)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Training shots: 117
# Test shots: 39
# Validation shots: 40
# Loaded model from models/cph_cmod_random_256_shots_60%_flattop.pkl
